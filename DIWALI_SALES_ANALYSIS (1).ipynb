# %% [markdown]
# #### **PROBLEM STATEMENT**

# %% [markdown]
# **The goal of this project is to analyze Diwali sales data to understand
# customer purchasing behavior based on gender, age group, state,
# and product categories.**

# %% [markdown]
# #### **IMPORT LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### **LOADING DATASET**

# %%
df = pd.read_csv('Diwali Sales Data.csv', encoding='latin-1')
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# #### **DATASET OVERVIEW**

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %% [markdown]
# #### **DATA CLEANING**

# %% [markdown]
# 1.Remove Unwanted Columns

# %%
df.drop(['Status','unnamed1'],axis = 1, inplace = True)

# %% [markdown]
# 2.Check Null Values

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# 3.Remove Rows with Missing Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# 4.Reset Index After Dropping Rows

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# 5.Change Data Type

# %%
df['Amount'] = df['Amount'].astype('int')

# %% [markdown]
# #### **EDA(EXPLORATORY DATA ANALYSIS)**

# %% [markdown]
# **1.DATA ANALYSIS**

# %% [markdown]
# 1.Gender Frequency Analysis

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    7832
# M    3407
# Name: count, dtype: int64

# %% [markdown]
# 2.Filter Female Customers

# %%
df[df['Gender'] == 'F']
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903   Sanskriti  P00125942      F     26-35   28               0
# 1      1000732      Kartik  P00110942      F     26-35   35               1
# 2      1001990       Bindu  P00118542      F     26-35   35               1
# 6      1001132        Balk  P00018042      F     18-25   25               1
# 8      1003650       Ginny  P00031142      F     26-35   26               1
# ...        ...         ...        ...    ...       ...  ...             ...
# 11229  1003032    Matthias  P00058042      F     26-35   33               0
# 11230  1004344  Hildebrand  P00185442      F     26-35   27               1
# 11233  1004140   Bertelson  P00057442      F     26-35   31               1
# 11236  1001209       Oshin  P00201342      F     36-45   40               0
# 11238  1002744     Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# 3.Total Spending by Female Customers

# %%
df[df['Gender'] == 'F']['Amount'].sum()
# Out:
# np.int64(74335853)

# %% [markdown]
# 4.Sort Transactions by Amount

# %%
df.sort_values(by='Amount', ascending=False)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11234  1000695      Manning  P00296942      M     18-25   19               1
# 11235  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11236  1001209        Oshin  P00201342      F     36-45   40               0
# 11237  1004023       Noonan  P00059442      M     36-45   37               0
# 11238  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# 5.Top 10 Highest Purchases

# %%
df.sort_values(by='Amount', ascending=False).head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1003224     Kushal  P00205642      M     26-35   35               0
# 8  1003650      Ginny  P00031142      F     26-35   26               1
# 9  1003829   Harshita  P00200842      M     26-35   34               0
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %% [markdown]
# 6.Unique States

# %%
df['State'].unique()
# Out:
# array(['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Jharkhand', 'Kerala',
#        'Haryana', 'Madhya Pradesh', 'Bihar', 'Rajasthan', 'Uttarakhand',
#        'Telangana', 'Punjab'], dtype=object)

# %% [markdown]
# 7.Number of Unique States

# %%
df['State'].nunique()
# Out:
# 16

# %% [markdown]
# 8.State-wise Sales

# %%
state_sales = df.groupby('State')['Amount'].sum().sort_values(ascending=False)
state_sales
# Out:
# State
# Uttar Pradesh       19374968
# Maharashtra         14427543
# Karnataka           13523540
# Delhi               11603818
# Madhya Pradesh       8101142
# Andhra Pradesh       8037146
# Himachal Pradesh     4963368
# Haryana              4220175
# Bihar                4022757
# Gujarat              3946082
# Kerala               3894491
# Jharkhand            3026456
# Uttarakhand          2520944
# Rajasthan            1909409
# Punjab               1525800
# Telangana            1151490
# Name: Amount, dtype: int64

# %% [markdown]
# 9.Pivot Table Analysis

# %%
pd.pivot_table(df, values='Amount', index='Gender', columns='Marital_Status', aggfunc='sum')
# Out:
# Marital_Status         0         1
# Gender
# F               43786646  30549207
# M               18338738  13574538

# %% [markdown]
# **2.VISUALIZATION**

# %% [markdown]
# 1.Gender Distribution

# %%
sns.countplot(x='Gender', data=df)
plt.title("Gender Distribution of Customers")
plt.show()

# %% [markdown]
# 2.Age Group vs Gender

# %%
sns.countplot(x='Age Group', hue='Gender', data=df)
plt.title("Age Group Distribution by Gender")
plt.show()

# %% [markdown]
# 3.Top States by Sales

# %%
state_sales.plot(kind='bar')
plt.title("Top 10 States by Sales")
plt.xlabel("State")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# 4.Total Sales by Gender

# %%
sales_gen = df.groupby('Gender')['Amount'].sum().reset_index()

sns.barplot(x='Gender', y='Amount', data=sales_gen)
plt.title("Total Sales by Gender")
plt.show()

# %% [markdown]
# 5.Product Category Sales

# %%
category_sales = df.groupby('Product_Category')['Amount'].sum().sort_values(ascending=False)

sns.barplot(x=category_sales.values, y=category_sales.index)
plt.title("Sales by Product Category")
plt.xlabel("Total Sales")
plt.ylabel("Product Category")
plt.show()

# %% [markdown]
# #### **INSIGHTS**

# %% [markdown]
# 1. Female customers contribute more to total sales than male customers.
# 2. The 26–35 age group has the highest number of buyers.
# 3. Uttar Pradesh, Maharashtra, and Karnataka generate the highest sales.
# 4. Food and clothing categories have the highest demand.
